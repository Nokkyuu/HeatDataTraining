# %% [markdown]
# # Detection algorithm
# ## First thoughts

# %% [markdown]
# There are many variables missing for a best case detection mechanism, like outside temperature, backflow temperature, when day or nighttime shutdown is and so on. <br>
# Furthermore, it is important to think about wether false positive or false negatives are more harmful, as no algorithm will (probably) be 100% accurate. <br><br>
#
# I will start with a simple detection mechanism for domestic hot water, which can than be advanced into a detection model for forward flow temperatures at a later stage. <br><br>
#
# For real time detection I would suggest to train a time series model like ARIMAX and compare expected values with actual values.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df = pd.read_csv("combined_data.csv", parse_dates=["timestamp"])
df.set_index("timestamp", inplace=True)

df.head()
# Out:
#                             avg  min_v  max_v  nighttime  time_diff_min  \
# timestamp
# 2022-12-07 01:15:00+00:00  65.7   64.1   67.2       True             15
# 2022-12-07 01:15:00+00:00  65.2   63.5   66.7       True             15
# 2022-12-07 01:30:00+00:00  64.7   62.5   66.8       True             15
# 2022-12-07 01:30:00+00:00  65.3   63.1   67.2       True             15
# 2022-12-07 01:45:00+00:00  64.3   62.5   66.6       True             15
#
#                            T_diff     type    ID
# timestamp
# 2022-12-07 01:15:00+00:00     3.1  forward  S3C1
# 2022-12-07 01:15:00+00:00     3.2  forward  S3C1
# 2022-12-07 01:30:00+00:00     4.3  forward  S3C1
# 2022-12-07 01:30:00+00:00     4.1  forward  S3C1
# 2022-12-07 01:45:00+00:00     4.1  forward  S3C1

# %%
def find_anomaly_domestic(dataset):
    #creating a quick and dirty anomaly detector function that works only on domestic hot water data for now
    df_domestic = dataset[dataset['type'] == 'domestic'].copy()
    rolling_mean = df_domestic['avg'].rolling(window=24, min_periods=1).mean() # roling means
    rolling_std = df_domestic['avg'].rolling(window=24, min_periods=1).std()
    df_domestic['anomaly'] = np.abs(df_domestic['avg'] - rolling_mean) > 2 * rolling_std
    anomalies = {}
    in_anomaly = False
    period_count = 1
    for idx, row in df_domestic.iterrows():
        if row['anomaly'] and not in_anomaly:
            start = idx
            in_anomaly = True
        elif not row['anomaly'] and in_anomaly:
            end = prev_idx
            anomalies[f"Period {period_count}"] = [
                start.strftime('%A'), start.strftime('%H:%M'),
                end.strftime('%A'), end.strftime('%H:%M')
            ]
            period_count += 1
            in_anomaly = False
        prev_idx = idx
        
    if in_anomaly:
        end = prev_idx
        anomalies[f"Period {period_count}"] = [
            start.strftime('%A'), start.strftime('%H:%M'),
            end.strftime('%A'), end.strftime('%H:%M')
        ]
    return anomalies

# %%
find_anomaly_domestic(df)
# Out:
# {'Period 1': ['Wednesday', '09:30', 'Wednesday', '09:30'],
#  'Period 2': ['Wednesday', '19:00', 'Wednesday', '19:00'],
#  'Period 3': ['Friday', '08:45', 'Friday', '08:45'],
#  'Period 4': ['Friday', '13:15', 'Friday', '13:15'],
#  'Period 5': ['Friday', '16:15', 'Friday', '16:15'],
#  'Period 6': ['Friday', '21:45', 'Friday', '21:45'],
#  'Period 7': ['Saturday', '07:15', 'Saturday', '07:15'],
#  'Period 8': ['Saturday', '15:30', 'Saturday', '15:45'],
#  'Period 9': ['Saturday', '19:45', 'Saturday', '19:45'],
#  'Period 10': ['Sunday', '05:45', 'Sunday', '05:45'],
#  'Period 11': ['Monday', '07:00', 'Monday', '07:00'],
#  'Period 12': ['Monday', '13:15', 'Monday', '13:15'],
#  'Period 13': ['Monday', '18:15', 'Monday', '18:15'],
#  'Period 14': ['Tuesday', '04:30', 'Tuesday', '04:30'],
#  'Period 15': ['Tuesday', '13:45', 'Tuesday', '13:45'],
#  'Period 16': ['Wednesday', '05:30', 'Wednesday', '05:45'],
#  'Period 17': ['Wednesday', '15:30', 'Wednesday', '15:30'],
#  'Period 18': ['Thursday', '11:30', 'Thursday', '11:30'],
#  'Period 19': ['Thursday', '15:00', 'Thursday', '15:00'],
#  'Period 20': ['Friday', '07:30', 'Friday', '07:30'],
#  'Period 21': ['Friday', '20:15', 'Friday', '20:15'],
#  'Period 22': ['Saturday', '16:00', 'Saturday', '16:00'],
#  'Period 23': ['Sunday', '13:15', 'Sunday', '13:15'],
#  'Period 24': ['Sunday', '16:15', 'Sunday', '16:15'],
#  'Period 25': ['Sunday', '19:30', 'Sunday', '19:30'],
#  'Period 26': ['Tuesday', '06:15', 'Tuesday', '06:30'],
#  'Period 27': ['Tuesday', '08:15', 'Tuesday', '08:30'],
#  'Period 28': ['Tuesday', '17:45', 'Tuesday', '17:45'],
#  'Period 29': ['Tuesday', '19:30', 'Tuesday', '21:45'],
#  'Period 30': ['Tuesday', '22:15', 'Tuesday', '23:15'],
#  'Period 31': ['Thursday', '08:00', 'Thursday', '08:15'],
#  'Period 32': ['Thursday', '12:30', 'Thursday', '12:30'],
#  'Period 33': ['Thursday', '14:15', 'Thursday', '14:15'],
#  'Period 34': ['Thursday', '17:30', 'Thursday', '17:30'],
#  'Period 35': ['Friday', '06:45', 'Friday', '06:45'],
#  'Period 36': ['Sunday', '08:45', 'Sunday', '08:45'],
#  'Period 37': ['Monday', '06:45', 'Monday', '06:45'],
#  'Period 38': ['Monday', '13:30', 'Monday', '13:30'],
#  'Period 39': ['Tuesday', '09:00', 'Tuesday', '09:00'],
#  'Period 40': ['Wednesday', '14:45', 'Wednesday', '14:45'],
#  'Period 41': ['Friday', '11:30', 'Friday', '11:30'],
#  'Period 42': ['Saturday', '21:15', 'Saturday', '21:15'],
#  'Period 43': ['Monday', '07:15', 'Monday', '07:15'],
#  'Period 44': ['Wednesday', '10:30', 'Wednesday', '10:30'],
#  'Period 45': ['Thursday', '08:45', 'Thursday', '08:45'],
#  'Period 46': ['Thursday', '12:45', 'Thursday', '12:45'],
#  'Period 47': ['Sunday', '15:00', 'Sunday', '15:00'],
#  'Period 48': ['Monday', '03:30', 'Monday', '03:30'],
#  'Period 49': ['Tuesday', '04:45', 'Tuesday', '04:45'],
#  'Period 50': ['Tuesday', '12:30', 'Tuesday', '12:30'],
#  'Period 51': ['Wednesday', '17:45', 'Wednesday', '17:45'],
#  'Period 52': ['Thursday', '07:30', 'Thursday', '07:30'],
#  'Period 53': ['Thursday', '17:45', 'Thursday', '17:45'],
#  'Period 54': ['Saturday', '06:30', 'Saturday', '06:30'],
#  'Period 55': ['Sunday', '03:15', 'Sunday', '03:15'],
#  'Period 56': ['Monday', '09:00', 'Monday', '09:00'],
#  'Period 57': ['Monday', '17:30', 'Monday', '17:30'],
#  'Period 58': ['Tuesday', '12:30', 'Tuesday', '12:30'],
#  'Period 59': ['Thursday', '08:15', 'Thursday', '08:15'],
#  'Period 60': ['Friday', '15:30', 'Friday', '18:00'],
#  'Period 61': ['Sunday', '12:15', 'Sunday', '12:15'],
#  'Period 62': ['Tuesday', '13:15', 'Tuesday', '13:15'],
#  'Period 63': ['Wednesday', '17:15', 'Wednesday', '17:15'],
#  'Period 64': ['Thursday', '15:15', 'Thursday', '15:15'],
#  'Period 65': ['Thursday', '20:00', 'Thursday', '21:00'],
#  'Period 66': ['Saturday', '08:45', 'Saturday', '08:45'],
#  'Period 67': ['Tuesday', '04:15', 'Tuesday', '04:15'],
#  'Period 68': ['Wednesday', '10:15', 'Wednesday', '10:30'],
#  'Period 69': ['Friday', '12:45', 'Friday', '14:15'],
#  'Period 70': ['Saturday', '18:15', 'Saturday', '18:15'],
#  'Period 71': ['Sunday', '08:00', 'Sunday', '08:00'],
#  'Period 72': ['Sunday', '10:45', 'Sunday', '11:00'],
#  'Period 73': ['Monday', '16:15', 'Monday', '16:15'],
#  'Period 74': ['Tuesday', '07:00', 'Tuesday', '07:15'],
#  'Period 75': ['Tuesday', '12:00', 'Tuesday', '13:00'],
#  'Period 76': ['Thursday', '06:45', 'Thursday', '06:45'],
#  'Period 77': ['Thursday', '18:15', 'Thursday', '18:15'],
#  'Period 78': ['Friday', '16:45', 'Friday', '16:45'],
#  'Period 79': ['Tuesday', '04:45', 'Tuesday', '04:45'],
#  'Period 80': ['Wednesday', '07:00', 'Wednesday', '07:00'],
#  'Period 81': ['Wednesday', '14:00', 'Wednesday', '14:45'],
#  'Period 82': ['Wednesday', '15:15', 'Wednesday', '15:15'],
#  'Period 83': ['Thursday', '18:00', 'Thursday', '18:00'],
#  'Period 84': ['Friday', '08:45', 'Friday', '08:45'],
#  'Period 85': ['Saturday', '06:45', 'Saturday', '06:45'],
#  'Period 86': ['Wednesday', '15:15', 'Wednesday', '15:15'],
#  'Period 87': ['Thursday', '20:15', 'Thursday', '20:15'],
#  'Period 88': ['Friday', '16:00', 'Friday', '16:00'],
#  'Period 89': ['Tuesday', '15:45', 'Tuesday', '15:45'],
#  'Period 90': ['Friday', '17:00', 'Friday', '17:00'],
#  'Period 91': ['Saturday', '01:15', 'Saturday', '01:15'],
#  'Period 92': ['Tuesday', '06:30', 'Tuesday', '06:30'],
#  'Period 93': ['Wednesday', '09:30', 'Wednesday', '09:30'],
#  'Period 94': ['Wednesday', '12:45', 'Wednesday', '12:45'],
#  'Period 95': ['Saturday', '18:15', 'Saturday', '18:15'],
#  'Period 96': ['Tuesday', '05:15', 'Tuesday', '05:15'],
#  'Period 97': ['Thursday', '17:15', 'Thursday', '17:15'],
#  'Period 98': ['Sunday', '10:15', 'Sunday', '10:15'],
#  'Period 99': ['Thursday', '07:15', 'Thursday', '07:15'],
#  'Period 100': ['Tuesday', '05:30', 'Tuesday', '05:30'],
#  'Period 101': ['Wednesday', '06:45', 'Wednesday', '06:45'],
#  'Period 102': ['Sunday', '17:15', 'Sunday', '17:15'],
#  'Period 103': ['Wednesday', '20:00', 'Wednesday', '20:00'],
#  'Period 104': ['Thursday', '15:15', 'Thursday', '15:15'],
#  'Period 105': ['Saturday', '16:45', 'Saturday', '16:45'],
#  'Period 106': ['Monday', '10:45', 'Monday', '10:45'],
#  'Period 107': ['Tuesday', '14:45', 'Tuesday', '14:45'],
#  'Period 108': ['Thursday', '07:45', 'Thursday', '07:45'],
#  'Period 109': ['Friday', '19:15', 'Friday', '19:15'],
#  'Period 110': ['Sunday', '09:00', 'Sunday', '09:00'],
#  'Period 111': ['Tuesday', '04:30', 'Tuesday', '04:30'],
#  'Period 112': ['Thursday', '16:15', 'Thursday', '16:15'],
#  'Period 113': ['Monday', '03:45', 'Monday', '03:45'],
#  'Period 114': ['Tuesday', '17:00', 'Tuesday', '17:00'],
#  'Period 115': ['Friday', '07:15', 'Friday', '07:15'],
#  'Period 116': ['Friday', '16:00', 'Friday', '16:00'],
#  'Period 117': ['Sunday', '08:45', 'Sunday', '08:45'],
#  'Period 118': ['Sunday', '19:45', 'Sunday', '19:45'],
#  'Period 119': ['Monday', '16:30', 'Monday', '16:30'],
#  'Period 120': ['Monday', '18:45', 'Monday', '18:45'],
#  'Period 121': ['Tuesday', '05:30', 'Tuesday', '05:30'],
#  'Period 122': ['Wednesday', '05:30', 'Wednesday', '05:30'],
#  'Period 123': ['Wednesday', '10:45', 'Wednesday', '10:45'],
#  'Period 124': ['Thursday', '04:15', 'Thursday', '04:15'],
#  'Period 125': ['Friday', '02:15', 'Friday', '03:30'],
#  'Period 126': ['Sunday', '08:45', 'Sunday', '09:00'],
#  'Period 127': ['Wednesday', '07:00', 'Wednesday', '09:00'],
#  'Period 128': ['Thursday', '14:00', 'Thursday', '15:00'],
#  'Period 129': ['Saturday', '09:15', 'Saturday', '09:15'],
#  'Period 130': ['Sunday', '10:00', 'Sunday', '10:30'],
#  'Period 131': ['Tuesday', '06:15', 'Tuesday', '06:15'],
#  'Period 132': ['Tuesday', '15:45', 'Tuesday', '16:15'],
#  'Period 133': ['Wednesday', '05:15', 'Wednesday', '05:45'],
#  'Period 134': ['Thursday', '03:30', 'Thursday', '03:30'],
#  'Period 135': ['Friday', '17:00', 'Friday', '17:00'],
#  'Period 136': ['Saturday', '10:00', 'Saturday', '10:00'],
#  'Period 137': ['Sunday', '13:30', 'Sunday', '13:30'],
#  'Period 138': ['Monday', '09:45', 'Monday', '09:45'],
#  'Period 139': ['Tuesday', '14:45', 'Tuesday', '14:45'],
#  'Period 140': ['Wednesday', '03:15', 'Wednesday', '04:45'],
#  'Period 141': ['Thursday', '04:45', 'Thursday', '05:00'],
#  'Period 142': ['Friday', '16:45', 'Friday', '17:00'],
#  'Period 143': ['Sunday', '15:15', 'Sunday', '15:15'],
#  'Period 144': ['Monday', '10:00', 'Monday', '10:00'],
#  'Period 145': ['Wednesday', '06:45', 'Wednesday', '06:45'],
#  'Period 146': ['Saturday', '17:45', 'Saturday', '17:45'],
#  'Period 147': ['Saturday', '19:30', 'Saturday', '19:30'],
#  'Period 148': ['Sunday', '15:45', 'Sunday', '15:45'],
#  'Period 149': ['Monday', '18:15', 'Monday', '19:45'],
#  'Period 150': ['Wednesday', '10:30', 'Wednesday', '10:30'],
#  'Period 151': ['Wednesday', '23:00', 'Wednesday', '23:15'],
#  'Period 152': ['Friday', '06:30', 'Friday', '07:45'],
#  'Period 153': ['Saturday', '08:30', 'Saturday', '08:30'],
#  'Period 154': ['Sunday', '14:15', 'Sunday', '14:15'],
#  'Period 155': ['Sunday', '22:45', 'Sunday', '22:45'],
#  'Period 156': ['Sunday', '23:15', 'Sunday', '23:15'],
#  'Period 157': ['Monday', '12:00', 'Monday', '12:45'],
#  'Period 158': ['Tuesday', '09:15', 'Tuesday', '10:15'],
#  'Period 159': ['Wednesday', '10:45', 'Wednesday', '10:45'],
#  'Period 160': ['Wednesday', '15:00', 'Wednesday', '15:00'],
#  'Period 161': ['Thursday', '11:15', 'Thursday', '11:30'],
#  'Period 162': ['Thursday', '15:00', 'Thursday', '15:00'],
#  'Period 163': ['Thursday', '19:15', 'Thursday', '20:00'],
#  'Period 164': ['Friday', '16:45', 'Friday', '17:15'],
#  'Period 165': ['Saturday', '00:15', 'Saturday', '00:15'],
#  'Period 166': ['Saturday', '10:30', 'Saturday', '10:30'],
#  'Period 167': ['Sunday', '04:30', 'Sunday', '04:45'],
#  'Period 168': ['Sunday', '10:30', 'Sunday', '11:00'],
#  'Period 169': ['Monday', '17:30', 'Monday', '17:30'],
#  'Period 170': ['Tuesday', '04:45', 'Tuesday', '04:45'],
#  'Period 171': ['Wednesday', '07:30', 'Wednesday', '07:45'],
#  'Period 172': ['Wednesday', '16:00', 'Wednesday', '16:00'],
#  'Period 173': ['Thursday', '05:45', 'Thursday', '05:45'],
#  'Period 174': ['Friday', '15:45', 'Friday', '15:45'],
#  'Period 175': ['Friday', '23:15', 'Friday', '23:30'],
#  'Period 176': ['Monday', '09:30', 'Monday', '09:30'],
#  'Period 177': ['Tuesday', '17:30', 'Tuesday', '17:45'],
#  'Period 178': ['Monday', '09:45', 'Monday', '09:45'],
#  'Period 179': ['Monday', '10:30', 'Monday', '12:00'],
#  'Period 180': ['Tuesday', '07:30', 'Tuesday', '07:30'],
#  'Period 181': ['Thursday', '10:15', 'Thursday', '11:00'],
#  'Period 182': ['Friday', '08:15', 'Friday', '08:15'],
#  'Period 183': ['Sunday', '16:00', 'Sunday', '16:00'],
#  'Period 184': ['Tuesday', '13:45', 'Tuesday', '13:45'],
#  'Period 185': ['Wednesday', '19:00', 'Wednesday', '19:00'],
#  'Period 186': ['Thursday', '09:00', 'Thursday', '09:00'],
#  'Period 187': ['Friday', '09:15', 'Friday', '09:15'],
#  'Period 188': ['Friday', '15:45', 'Friday', '15:45'],
#  'Period 189': ['Saturday', '08:15', 'Saturday', '08:30'],
#  'Period 190': ['Saturday', '11:30', 'Saturday', '11:30'],
#  'Period 191': ['Saturday', '19:30', 'Saturday', '19:30'],
#  'Period 192': ['Sunday', '21:30', 'Sunday', '21:30'],
#  'Period 193': ['Monday', '18:00', 'Monday', '18:00'],
#  'Period 194': ['Tuesday', '11:45', 'Tuesday', '11:45'],
#  'Period 195': ['Wednesday', '15:45', 'Wednesday', '15:45'],
#  'Period 196': ['Wednesday', '19:30', 'Wednesday', '19:30'],
#  'Period 197': ['Thursday', '10:30', 'Thursday', '10:45'],
#  'Period 198': ['Thursday', '12:15', 'Thursday', '12:15'],
#  'Period 199': ['Friday', '09:15', 'Friday', '09:15'],
#  'Period 200': ['Saturday', '09:00', 'Saturday', '09:00'],
#  'Period 201': ['Saturday', '19:30', 'Saturday', '20:15'],
#  'Period 202': ['Sunday', '12:30', 'Sunday', '13:45'],
#  'Period 203': ['Sunday', '18:30', 'Sunday', '19:00'],
#  'Period 204': ['Sunday', '21:15', 'Sunday', '21:15'],
#  'Period 205': ['Tuesday', '09:15', 'Tuesday', '09:15'],
#  'Period 206': ['Wednesday', '13:30', 'Wednesday', '13:30'],
#  'Period 207': ['Thursday', '06:30', 'Thursday', '07:00'],
#  'Period 208': ['Friday', '11:30', 'Friday', '11:30'],
#  'Period 209': ['Friday', '14:45', 'Friday', '14:45'],
#  'Period 210': ['Sunday', '10:45', 'Sunday', '10:45'],
#  'Period 211': ['Sunday', '19:00', 'Sunday', '19:00'],
#  'Period 212': ['Monday', '08:45', 'Monday', '09:00'],
#  'Period 213': ['Monday', '12:00', 'Monday', '12:00'],
#  'Period 214': ['Monday', '16:45', 'Monday', '17:00'],
#  'Period 215': ['Tuesday', '14:30', 'Tuesday', '14:30'],
#  'Period 216': ['Tuesday', '16:45', 'Tuesday', '16:45'],
#  'Period 217': ['Wednesday', '04:00', 'Wednesday', '04:15'],
#  'Period 218': ['Wednesday', '16:45', 'Wednesday', '16:45'],
#  'Period 219': ['Thursday', '13:15', 'Thursday', '13:15'],
#  'Period 220': ['Thursday', '15:45', 'Thursday', '15:45'],
#  'Period 221': ['Friday', '06:00', 'Friday', '06:00'],
#  'Period 222': ['Friday', '13:30', 'Friday', '13:30'],
#  'Period 223': ['Friday', '15:45', 'Friday', '15:45'],
#  'Period 224': ['Friday', '19:30', 'Friday', '19:30'],
#  'Period 225': ['Sunday', '08:45', 'Sunday', '08:45'],
#  'Period 226': ['Sunday', '19:00', 'Sunday', '19:00'],
#  'Period 227': ['Monday', '12:45', 'Monday', '12:45'],
#  'Period 228': ['Monday', '16:00', 'Monday', '16:15'],
#  'Period 229': ['Tuesday', '05:15', 'Tuesday', '05:30'],
#  'Period 230': ['Wednesday', '07:45', 'Wednesday', '07:45'],
#  'Period 231': ['Friday', '05:15', 'Friday', '05:15'],
#  'Period 232': ['Friday', '14:45', 'Friday', '15:00'],
#  'Period 233': ['Sunday', '11:00', 'Sunday', '11:00'],
#  'Period 234': ['Sunday', '16:30', 'Sunday', '16:30'],
#  'Period 235': ['Monday', '10:30', 'Monday', '10:30'],
#  'Period 236': ['Monday', '13:15', 'Monday', '13:15'],
#  'Period 237': ['Tuesday', '15:15', 'Tuesday', '15:15'],
#  'Period 238': ['Wednesday', '22:00', 'Wednesday', '22:00'],
#  'Period 239': ['Thursday', '07:30', 'Thursday', '07:30'],
#  'Period 240': ['Friday', '12:15', 'Friday', '13:45'],
#  'Period 241': ['Saturday', '15:15', 'Saturday', '15:15'],
#  'Period 242': ['Sunday', '10:15', 'Sunday', '10:15'],
#  'Period 243': ['Monday', '06:45', 'Monday', '06:45'],
#  'Period 244': ['Monday', '12:15', 'Monday', '12:15'],
#  'Period 245': ['Tuesday', '09:00', 'Tuesday', '09:00'],
#  'Period 246': ['Tuesday', '21:45', 'Tuesday', '21:45'],
#  'Period 247': ['Wednesday', '23:30', 'Wednesday', '23:30'],
#  'Period 248': ['Sunday', '06:45', 'Sunday', '06:45'],
#  'Period 249': ['Sunday', '17:00', 'Sunday', '17:00'],
#  'Period 250': ['Tuesday', '20:15', 'Tuesday', '20:15'],
#  'Period 251': ['Wednesday', '11:30', 'Wednesday', '11:30'],
#  'Period 252': ['Wednesday', '15:00', 'Wednesday', '15:15'],
#  'Period 253': ['Thursday', '18:45', 'Thursday', '18:45'],
#  'Period 254': ['Saturday', '07:45', 'Saturday', '07:45'],
#  'Period 255': ['Saturday', '16:15', 'Saturday', '16:15'],
#  'Period 256': ['Monday', '19:30', 'Monday', '19:30'],
#  'Period 257': ['Tuesday', '07:00', 'Tuesday', '07:00'],
#  'Period 258': ['Tuesday', '08:30', 'Tuesday', '08:45'],
#  'Period 259': ['Tuesday', '15:45', 'Tuesday', '15:45'],
#  'Period 260': ['Thursday', '06:30', 'Thursday', '06:30'],
#  'Period 261': ['Thursday', '09:15', 'Thursday', '09:30'],
#  'Period 262': ['Friday', '04:00', 'Friday', '04:00'],
#  'Period 263': ['Sunday', '07:45', 'Sunday', '07:45'],
#  'Period 264': ['Monday', '08:00', 'Monday', '08:15'],
#  'Period 265': ['Tuesday', '18:30', 'Tuesday', '18:30'],
#  'Period 266': ['Wednesday', '05:00', 'Wednesday', '05:00'],
#  'Period 267': ['Wednesday', '07:15', 'Wednesday', '07:15'],
#  'Period 268': ['Thursday', '06:45', 'Thursday', '06:45'],
#  'Period 269': ['Thursday', '12:00', 'Thursday', '12:15'],
#  'Period 270': ['Friday', '15:15', 'Friday', '15:30'],
#  'Period 271': ['Saturday', '12:45', 'Saturday', '13:00'],
#  'Period 272': ['Sunday', '08:45', 'Sunday', '09:15'],
#  'Period 273': ['Sunday', '12:00', 'Sunday', '12:30'],
#  'Period 274': ['Monday', '16:30', 'Monday', '16:45'],
#  'Period 275': ['Monday', '20:00', 'Monday', '21:15'],
#  'Period 276': ['Tuesday', '07:00', 'Tuesday', '08:30'],
#  'Period 277': ['Wednesday', '11:45', 'Wednesday', '12:00'],
#  'Period 278': ['Wednesday', '20:45', 'Wednesday', '20:45'],
#  'Period 279': ['Friday', '09:45', 'Friday', '11:15'],
#  'Period 280': ['Saturday', '10:00', 'Saturday', '12:15'],
#  'Period 281': ['Thursday', '05:30', 'Thursday', '05:30'],
#  'Period 282': ['Thursday', '07:30', 'Thursday', '07:30'],
#  'Period 283': ['Saturday', '12:00', 'Saturday', '12:00'],
#  'Period 284': ['Saturday', '16:30', 'Saturday', '16:30'],
#  'Period 285': ['Sunday', '09:00', 'Sunday', '09:00'],
#  'Period 286': ['Monday', '19:45', 'Monday', '19:45'],
#  'Period 287': ['Tuesday', '05:45', 'Tuesday', '05:45'],
#  'Period 288': ['Saturday', '14:15', 'Saturday', '14:15'],
#  'Period 289': ['Sunday', '13:00', 'Sunday', '13:00'],
#  'Period 290': ['Tuesday', '12:00', 'Tuesday', '12:00'],
#  'Period 291': ['Tuesday', '17:00', 'Tuesday', '17:00'],
#  'Period 292': ['Thursday', '00:30', 'Thursday', '00:30'],
#  'Period 293': ['Friday', '14:45', 'Friday', '14:45'],
#  'Period 294': ['Friday', '20:00', 'Friday', '20:00'],
#  'Period 295': ['Saturday', '03:15', 'Saturday', '03:15'],
#  'Period 296': ['Wednesday', '06:00', 'Wednesday', '06:00'],
#  'Period 297': ['Thursday', '10:15', 'Thursday', '10:15'],
#  'Period 298': ['Saturday', '22:30', 'Saturday', '22:30'],
#  'Period 299': ['Wednesday', '09:45', 'Wednesday', '09:45'],
#  'Period 300': ['Saturday', '06:30', 'Saturday', '06:30'],
#  'Period 301': ['Monday', '11:15', 'Monday', '11:15'],
#  'Period 302': ['Thursday', '06:30', 'Thursday', '06:30'],
#  'Period 303': ['Friday', '05:00', 'Friday', '05:00'],
#  'Period 304': ['Sunday', '09:15', 'Sunday', '09:15'],
#  'Period 305': ['Monday', '09:00', 'Monday', '09:00'],
#  'Period 306': ['Monday', '20:30', 'Monday', '20:30'],
#  'Period 307': ['Wednesday', '09:15', 'Wednesday', '09:15'],
#  'Period 308': ['Wednesday', '15:45', 'Wednesday', '15:45'],
#  'Period 309': ['Thursday', '07:45', 'Thursday', '07:45'],
#  'Period 310': ['Friday', '11:45', 'Friday', '11:45'],
#  'Period 311': ['Monday', '07:45', 'Monday', '07:45'],
#  'Period 312': ['Tuesday', '22:00', 'Tuesday', '22:00'],
#  'Period 313': ['Friday', '07:00', 'Friday', '07:00'],
#  'Period 314': ['Monday', '21:45', 'Monday', '21:45'],
#  'Period 315': ['Friday', '08:45', 'Friday', '08:45'],
#  'Period 316': ['Friday', '16:30', 'Friday', '16:30'],
#  'Period 317': ['Tuesday', '10:45', 'Tuesday', '10:45'],
#  'Period 318': ['Wednesday', '22:30', 'Wednesday', '22:30'],
#  'Period 319': ['Friday', '22:15', 'Friday', '22:15'],
#  'Period 320': ['Monday', '04:15', 'Monday', '04:15'],
#  'Period 321': ['Monday', '10:30', 'Monday', '10:30'],
#  'Period 322': ['Friday', '03:30', 'Friday', '03:30'],
#  'Period 323': ['Saturday', '15:00', 'Saturday', '15:00']}
